# %%
import pandas as pd
import numpy as np

# %%
cuisines = ['Italian', 'Chinese', 'Mexican', 'Japanese', 'French', 'American']

# %%
for cui in cuisines:
    df = pd.read_csv(cui+"_data.csv", header=0)
    print(df.shape)
    display(df.head())
# Out:
# (1000, 9)
#               business_id                   name  cuisine  \
# 0  hdiuRS9sVZSMReZm4oV5SA              Da Andrea  Italian
# 1  16ZnHpuaaBt92XWeJHCC5A             Olio e Più  Italian
# 2  VmdyRRMtUXOWV7F7w0ImwQ  Piccola Cucina Uptown  Italian
# 3  DoSU8IPq-Py_YV3kYmXPfQ    Trattoria Trecolori  Italian
# 4  rp8S7scxOkVVeG7dNneMGQ               L'Artusi  Italian
#
#                                  address   latitude  longitude  \
# 0      '35 W 13th St New York, NY 10011'  40.736218 -73.995970
# 1   '3 Greenwich Ave New York, NY 10014'  40.733798 -73.999774
# 2     '106 E 60th St New York, NY 10022'  40.763174 -73.969046
# 3  '254 West 47th St New York, NY 10036'  40.759876 -73.986767
# 4     '228 W 10th St New York, NY 10014'  40.733720 -74.005130
#
#    number_of_reviews  rating      inserted_at_time_stamp
# 0               1823     4.5  2023-02-26 00:31:36.432931
# 1               4041     4.5  2023-02-26 00:31:36.432985
# ...

# %%
for cui in cuisines:
    df = pd.read_csv(cui+"_data.csv", header=0)
    df_clean = df.drop_duplicates(subset=['business_id'])
    df_clean.to_csv('/Users/camillechu/Desktop/Spring_23/Cloud/HW1/yelp-scraper/'+cui+'_data_clean.csv', index=False, header=True)
    df_clean_disp = pd.read_csv(cui+"_data_clean.csv", header=0)
    print(df_clean_disp.shape)
    display(df_clean_disp.head())
# Out:
# (1000, 9)
#               business_id                   name  cuisine  \
# 0  hdiuRS9sVZSMReZm4oV5SA              Da Andrea  Italian
# 1  16ZnHpuaaBt92XWeJHCC5A             Olio e Più  Italian
# 2  VmdyRRMtUXOWV7F7w0ImwQ  Piccola Cucina Uptown  Italian
# 3  DoSU8IPq-Py_YV3kYmXPfQ    Trattoria Trecolori  Italian
# 4  rp8S7scxOkVVeG7dNneMGQ               L'Artusi  Italian
#
#                                  address   latitude  longitude  \
# 0      '35 W 13th St New York, NY 10011'  40.736218 -73.995970
# 1   '3 Greenwich Ave New York, NY 10014'  40.733798 -73.999774
# 2     '106 E 60th St New York, NY 10022'  40.763174 -73.969046
# 3  '254 West 47th St New York, NY 10036'  40.759876 -73.986767
# 4     '228 W 10th St New York, NY 10014'  40.733720 -74.005130
#
#    number_of_reviews  rating      inserted_at_time_stamp
# 0               1823     4.5  2023-02-26 00:31:36.432931
# 1               4041     4.5  2023-02-26 00:31:36.432985
# ...
